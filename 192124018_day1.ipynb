# %%
import pandas as pd

df = pd.read_csv('data1_1.csv')
# Then, attempt to access the columns
distinct_department_ids_1 = df['DEPARTMENT_ID'].drop_duplicates()
distinct_department_ids_2 = df['MANAGER_ID'].drop_duplicates()
distinct_department_ids_3 = df['LOCATION_ID'].drop_duplicates()

print(distinct_department_ids_1)
print(distinct_department_ids_2)
print(distinct_department_ids_3)
# Out:
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50
# 5      60
# 6      70
# 7      80
# 8      90
# 9     100
# 10    110
# 11    120
# 12    130
# 13    140
# 14    150
# 15    160
# 16    170
# 17    180
# 18    190
# 19    200
# 20    210
# 21    220
# 22    230
# 23    240
# 24    250
# 25    260
# 26    270
# Name: DEPARTMENT_ID, dtype: int64
# 0     200
# 1     201
# 2     114
# 3     203
# 4     121
# 5     103
# 6     204
# 7     145
# 8     100
# 9     108
# 10    205
# 11      0
# Name: MANAGER_ID, dtype: int64
# 0    1700
# 1    1800
# 3    2400
# 4    1500
# 5    1400
# 6    2700
# 7    2500
# Name: LOCATION_ID, dtype: int64

# %%
import pandas as pd

data = {
    'EMPLOYEE_ID': [102, 101, 101, 201, 114, 122, 200, 176, 176, 200],
    'START_DATE': ['2001-01-13', '1997-09-21', '2001-10-28', '2004-02-17', '2006-03-24', '2007-01-01', '1995-09-17', '2006-03-24', '2007-01-01', '2002-07-01'],
    'END_DATE': ['2006-07-24', '2001-10-27', '2005-03-15', '2007-12-19', '2007-12-31', '2007-12-31', '2001-06-17', '2006-12-31', '2007-12-31', '2006-12-31'],
    'JOB_ID': ['IT_PROG', 'AC_ACCOUNT', 'AC_MGR', 'MK_REP', 'ST_CLERK', 'ST_CLERK', 'AD_ASST', 'SA_REP', 'SA_MAN', 'AC_ACCOUNT'],
    'DEPARTMENT_ID': [60, 110, 110, 20, 50, 50, 90, 80, 80, 90]
}
df = pd.DataFrame(data)
df.to_csv('employee_data.csv', index=False)
df_1= pd.read_csv('employee_data.csv')
job_counts = df.groupby('EMPLOYEE_ID')['JOB_ID'].nunique()
employees_with_multiple_jobs = job_counts[job_counts >= 2]
print(employees_with_multiple_jobs)
# Out:
# EMPLOYEE_ID
# 101    2
# 176    2
# 200    2
# Name: JOB_ID, dtype: int64

# %%
import pandas as pd

data = {
    'JOB_ID': ['AD_PRES', 'AD_VP', 'AD_ASST', 'FI_MGR', 'FI_ACCOUNT', 'AC_MGR', 'AC_ACCOUNT', 'SA_MAN', 'SA_REP', 'PU_MAN', 'PU_CLERK', 'ST_MAN', 'ST_CLERK', 'SH_CLERK', 'IT_PROG', 'MK_MAN', 'MK_REP', 'HR_REP', 'PR_REP'],
    'JOB_TITLE': ['President', 'Administration Vice President', 'Administration Assistant', 'Finance Manager', 'Accountant', 'Accounting Manager', 'Public Accountant', 'Sales Manager', 'Sales Representative', 'Purchasing Manager', 'Purchasing Clerk', 'Stock Manager', 'Stock Clerk', 'Shipping Clerk', 'Programmer', 'Marketing Manager', 'Marketing Representative', 'Human Resources Representative', 'Public Relations Representative'],
    'MIN_SALARY': [20080, 15000, 3000, 8200, 4200, 8200, 4200, 10000, 6000, 8000, 2500, 5500, 2008, 2500, 4000, 9000, 2000, 2008, 4500],
    'MAX_SALARY': [40000, 30000, 6000, 16000, 9000, 16000, 9000, 20080, 12008, 15000, 5500, 8500, 5000, 5500, 10000, 15000, 9000, 5000, 10500]
}

df = pd.DataFrame(data)

# Convert the DataFrame to a CSV file
df.to_csv('job_data.csv', index=False)
a= pd.read_csv('job_data.csv')
sorted_df = df.sort_values(by='JOB_TITLE', ascending=False)
print(sorted_df)
# Out:
#         JOB_ID                        JOB_TITLE  MIN_SALARY  MAX_SALARY
# 11      ST_MAN                    Stock Manager        5500        8500
# 12    ST_CLERK                      Stock Clerk        2008        5000
# 13    SH_CLERK                   Shipping Clerk        2500        5500
# 8       SA_REP             Sales Representative        6000       12008
# 7       SA_MAN                    Sales Manager       10000       20080
# 9       PU_MAN               Purchasing Manager        8000       15000
# 10    PU_CLERK                 Purchasing Clerk        2500        5500
# 18      PR_REP  Public Relations Representative        4500       10500
# 6   AC_ACCOUNT                Public Accountant        4200        9000
# 14     IT_PROG                       Programmer        4000       10000
# 0      AD_PRES                        President       20080       40000
# 16      MK_REP         Marketing Representative        2000        9000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (replace with your actual historical stock price data)
data = {
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
    'Price': [2800, 2810, 2790, 2820, 2835]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Convert the 'Date' column to a datetime object
df['Date'] = pd.to_datetime(df['Date'])

# Specify the date range you want to plot
start_date = '2023-01-02'
end_date = '2023-01-04'

# Filter the data for the specified date range
filtered_data = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(filtered_data['Date'], filtered_data['Price'], marker='o', linestyle='-')
plt.title('Alphabet Inc. Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (replace with your actual trading volume data)
data = {
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
    'Volume': [1000000, 1100000, 900000, 1200000, 950000]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Convert the 'Date' column to a datetime object
df['Date'] = pd.to_datetime(df['Date'])

# Specify the date range you want to plot
start_date = '2023-01-02'
end_date = '2023-01-04'

# Filter the data for the specified date range
filtered_data = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(filtered_data['Date'], filtered_data['Volume'])
plt.title('Alphabet Inc. Trading Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import csv
import numpy as np
data = [
    ["OrderDate", "Region", "Manager", "SalesMan", "Item", "Units", "Unit_price", "Sale_amt"],
    ["1-6-18", "East", "Martha", "Alexander", "Television", 95, 1198.00, 13810.00],
    ["1-23-18", "Central", "Hermann", "Shelli", "Home Theater", 50, 500.00, 25000.00],
    ["2-9-18", "Central", "Hermann", "Luis", "Television", 36, 1198.00, 43128.00],
    ["2-26-18", "Central", "Timothy", "David", "Cell Phone", 27, 225.00, 6075.00],
    ["3-15-18", "West", "Timothy", "Stephen", "Television", 56, 1198.00, 67088.00],
    ["4-1-18", "East", "Martha", "Alexander", "Home Theater", 60, 500.00, 30000.00],
    ["4-18-18", "Central", "Martha", "Steven", "Television", 75, 1198.00, 89850.00],
    ["5-5-18", "Central", "Hermann", "Luis", "Television", 90, 1198.00, 107820.00],
    ["5-22-18", "West", "Douglas", "Michael", "Television", 32, 1198.00, 38336.00],
    ["6-8-18", "East", "Martha", "Alexander", "Home Theater", 60, 500.00, 30000.00],
    ["6-25-18", "Central", "Hermann", "Sigal", "Television", 90, 1198.00, 107820.00],
    ["7-12-18", "East", "Martha", "Diana", "Home Theater", 29, 500.00, 14500.00],
    ["7-29-18", "East", "Douglas", "Karen", "Home Theater", 81, 500.00, 40500.00],
    ["8-15-18", "East", "Martha", "Alexander", "Television", 35, 1198.00, 41930.00],
    ["9-1-18", "Central", "Douglas", "John", "Desk", 2, 125.00, 250.00],
    ["9-18-18", "East", "Martha", "Alexander", "Video Games", 16, 58.50, 936.00],
    ["10-5-18", "Central", "Hermann", "Sigal", "Home Theater", 28, 500.00, 14000.00],
    ["10-22-18", "East", "Martha", "Alexander", "Cell Phone", 64, 225.00, 14400.00]
]
df = pd.DataFrame(data)
table = pd.pivot_table(df, index='Item', values='Sale_amt', aggfunc=[np.max, np.min])
print("Pivot Table for Maximum and Minimum Sale Value of Items:")
print(pivot_table)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-b16bfefae4c5> in <cell line: 26>()
#      24 ]
#      25 df = pd.DataFrame(data)
# ---> 26 table = pd.pivot_table(df, index='data$Item', values='data$Sale_amt', aggfunc=[np.max, np.min])
#      27 print("Pivot Table for Maximum and Minimum Sale Value of Items:")
#      28 print(pivot_table)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      76         keys = []
#      77         for func in aggfunc:
# ---> 78             _table = __internal_pivot_table(
#      79                 data,
#      80                 values=values,
#
# ...

# %%
import pandas as pd
import csv
import numpy as np

data = [
    ["OrderDate", "Region", "Manager", "SalesMan", "Item", "Units", "Unit_price", "Sale_amt"],
    ["1-6-18", "East", "Martha", "Alexander", "Television", 95, 1198.00, 13810.00],
    ["1-23-18", "Central", "Hermann", "Shelli", "Home Theater", 50, 500.00, 25000.00],
    ["2-9-18", "Central", "Hermann", "Luis", "Television", 36, 1198.00, 43128.00],
    ["2-26-18", "Central", "Timothy", "David", "Cell Phone", 27, 225.00, 6075.00],
    ["3-15-18", "West", "Timothy", "Stephen", "Television", 56, 1198.00, 67088.00],
    ["4-1-18", "East", "Martha", "Alexander", "Home Theater", 60, 500.00, 30000.00],
    ["4-18-18", "Central", "Martha", "Steven", "Television", 75, 1198.00, 89850.00],
    ["5-5-18", "Central", "Hermann", "Luis", "Television", 90, 1198.00, 107820.00],
    ["5-22-18", "West", "Douglas", "Michael", "Television", 32, 1198.00, 38336.00],
    ["6-8-18", "East", "Martha", "Alexander", "Home Theater", 60, 500.00, 30000.00],
    ["6-25-18", "Central", "Hermann", "Sigal", "Television", 90, 1198.00, 107820.00],
    ["7-12-18", "East", "Martha", "Diana", "Home Theater", 29, 500.00, 14500.00],
    ["7-29-18", "East", "Douglas", "Karen", "Home Theater", 81, 500.00, 40500.00],
    ["8-15-18", "East", "Martha", "Alexander", "Television", 35, 1198.00, 41930.00],
    ["9-1-18", "Central", "Douglas", "John", "Desk", 2, 125.00, 250.00],
    ["9-18-18", "East", "Martha", "Alexander", "Video Games", 16, 58.50, 936.00],
    ["10-5-18", "Central", "Hermann", "Sigal", "Home Theater", 28, 500.00, 14000.00],
    ["10-22-18", "East", "Martha", "Alexander", "Cell Phone", 64, 225.00, 14400.00]
]

df = pd.DataFrame(data)

# Create a Pivot table to find the maximum and minimum sale value of items
pivot_table = df.pivot_table(index='Item', values='Sale_amt', aggfunc=[np.max, np.min])

print("Pivot Table for Maximum and Minimum Sale Value of Items:")
print(pivot_table)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-ba36c1b336a1> in <cell line: 30>()
#      28
#      29 # Create a Pivot table to find the maximum and minimum sale value of items
# ---> 30 pivot_table = df.pivot_table(index='Item', values='Sale_amt', aggfunc=[np.max, np.min])
#      31
#      32 print("Pivot Table for Maximum and Minimum Sale Value of Items:")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8729         from pandas.core.reshape.pivot import pivot_table
#    8730
# -> 8731         return pivot_table(
#    8732             self,
#    8733             values=values,
#
# ...
